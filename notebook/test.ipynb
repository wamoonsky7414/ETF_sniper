# %%
import pandas as pd
import numpy as np

# %%
pd.read_parquet(r'C:\Users\User\Documents\GitHub\ETF_sniper\data\00982A\holding\20251226.parquet')#['資料日期'][0]

# %%
pd.read_parquet(r'C:\Users\User\Documents\GitHub\ETF_sniper\data\00982A\holding\20251229.parquet')#['持股權重(%)'][0]

# %%
pd.read_parquet(r'C:\Users\User\Documents\GitHub\ETF_sniper\data\00982A\portfolio\20251229.parquet')

# %%
data = pd.read_excel(r"C:\Users\User\Documents\GitHub\ETF_sniper\data\00991A\download\20251226.xlsx", sheet_name=0)
data
