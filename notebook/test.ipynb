# %%
import pandas as pd
import numpy as np

# %%
data_1 = pd.read_parquet(r"C:\Users\User\Documents\GitHub\ETF_sniper\data\00982A\20251219.parquet")
data_2 = pd.read_parquet(r"C:\Users\User\Documents\GitHub\ETF_sniper\data\00982A\20251222.parquet")

# %%
data_1
# Out:
#     股票代號     股票名稱    持股權重       股數
# 0   2330      台積電  0.0890  1707000
# 1   3017       奇鋐  0.0661  1332000
# 2   6669       緯穎  0.0659   433000
# 3   5536      聖暉*  0.0634  2278000
# 4   2345       智邦  0.0483  1123000
# 5   2360       致茂  0.0366  1378000
# 6   2449     京元電子  0.0311  4084000
# 7   6139       亞翔  0.0306  1437000
# 8   6805      富世達  0.0305   577000
# 9   2383      台光電  0.0262   478000
# 10  2441       超豐  0.0254  8343000
# 11  3036       文曄  0.0252  4695000
# 12  2368      金像電  0.0251  1170000
# 13  3665    貿聯-KY  0.0235   447136
# 14  3264       欣銓  0.0229  7052000
# 15  5439       高技  0.0228  2011000
# 16  2308      台達電  0.0226   695000
# 17  6257       矽格  0.0225  6490000
# 18  2059       川湖  0.0222   173000
# 19  3231       緯創  0.0203  3996000
# 20  2428       興勤  0.0202  3157000
# 21  2451       創見  0.0198  2965000
# 22  2421       建準  0.0191  3457000
# 23  8299       群聯  0.0173   440000
# 24  2316      楠梓電  0.0159  4303000
# 25  2472      立隆電  0.0150  3971000
# ...

# %%
data_2
# Out:
#     股票代號     股票名稱    持股權重       股數
# 0   2330      台積電  0.0869  1707000
# 1   3017       奇鋐  0.0688  1332000
# 2   6669       緯穎  0.0661   433000
# 3   5536      聖暉*  0.0642  2278000
# 4   2345       智邦  0.0470  1123000
# 5   2360       致茂  0.0364  1378000
# 6   6805      富世達  0.0317   577000
# 7   2449     京元電子  0.0313  4084000
# 8   6139       亞翔  0.0309  1437000
# 9   8299       群聯  0.0273   690000
# 10  2383      台光電  0.0264   478000
# 11  2441       超豐  0.0264  8343000
# 12  3036       文曄  0.0254  4695000
# 13  2368      金像電  0.0253  1170000
# 14  3665    貿聯-KY  0.0229   447136
# 15  3264       欣銓  0.0227  7052000
# 16  2059       川湖  0.0226   173000
# 17  2308      台達電  0.0225   695000
# 18  5439       高技  0.0225  2011000
# 19  6257       矽格  0.0225  6490000
# 20  3231       緯創  0.0205  3996000
# 21  2428       興勤  0.0196  3157000
# 22  2421       建準  0.0193  3457000
# 23  2451       創見  0.0185  2965000
# 24  2316      楠梓電  0.0156  4303000
# 25  2472      立隆電  0.0148  3971000
# ...
